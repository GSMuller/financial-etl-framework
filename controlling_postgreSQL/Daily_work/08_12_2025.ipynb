# %%
# Bibliotecas
import pandas as pd
import numpy as np

# %%
## Conexção
import sys
sys.path.append(r'c:\\Users\\giovanni.5683\\GITHUB\\controlling_postgreSQL')
from conn import get_connection # type: ignore

conn = get_connection()

# %% [markdown]
# ##### Criação da table controle
# - Mapeando colunas:
#
# ['revenda','competencia','status','tipo_de_bonus','categoria_bonus','parcial_final','dta_pgto','dta_baixa','dta_inf_fab','dta_prevista','qtd_vendas','nd','$razao','indeferido','reavaliação','2024','proj_atacado','proj_pdi','proj_performance','$recebido','$custo_agregado','$recebido_efetivo','$df_positiva','$df_negativa','$comissao_vd','$info_fab','$proj_op','$proj_rebate_op','$proj_ipva_op','$proj_trade_op','$proj_equal_op','$proj_varejo_op','$proj_trade_op','$proj_ipva_op','$proj_varejo_op','$proj_tradein_op','$proj_total_op',$proj_dpto','$proj_rebate_dpto','$proj_ipva_dpto','$proj_trade_dpto','$proj_equal_dpto','$proj_varejo_dpto','$proj_trade_dpto','$proj_ipva_dpto','$proj_varejo_dpto','$proj_tradein_dpto','$proj_total_dpto,$op_vs_dpto,observacao,$a_receber,$dif_real]

# %%
query_controle = """
select * from byd.controle 
order by competencia desc
"""
df_controle = pd.read_sql_query(query_controle, conn)
df_controle
# Out:
# C:\Users\giovanni.5683\AppData\Local\Temp\ipykernel_18024\119087968.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_controle = pd.read_sql_query(query_controle, conn)
# Empty DataFrame
# Columns: [revenda, competencia, status, tipo_de_bonus, categoria_bonus, parcial_final, dta_pgto, dta_baixa, dta_inf_fab, dta_prevista, qtd_vendas, nd, $razao, indeferido, reavaliação, 2024, proj_atacado, proj_pdi, proj_performance, $recebido, $custo_agregado, $recebido_efetivo, $df_positiva, $df_negativa, $comissao_vd, $info_fab, $proj_op, $proj_rebate_op, $proj_ipva_op, $proj_trade_op, $proj_equal_op, $proj_varejo_op, $proj_tradein_op, $proj_total_op, $proj_dpto, $proj_rebate_dpto, $proj_ipva_dpto, $proj_trade_dpto, $proj_equal_dpto, $proj_varejo_dpto, $proj_tradein_dpto, observação, $a_receber, $dif_real]
# Index: []
#
# ...
