# %%
## Bibliotecas
import pandas as pd
import bokeh.plotting as bp
import sys
sys.path.append(r'C:\Users\giovanni.5683\GITHUB\controlling_postgreSQL')  # Adiciona o diretório onde está conn.py
from conn import get_connection
engine = get_connection()
cursor = engine.cursor()

# %%
## Conexão com o banco de dados
bonus_view_query = """ SELECT * FROM byd.bonus_view
WHERE competencia IN ('Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro')
""" 
bonus_view_df = pd.read_sql(bonus_view_query, engine)
# Out:
# C:\Users\giovanni.5683\AppData\Local\Temp\ipykernel_1972\2469863039.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   bonus_view_df = pd.read_sql(bonus_view_query, engine)

# %%
## Atualizado o bonus_dpto

bonus_view_df = bonus_view_df[['idnfsexterno','data_final_venda','competencia','des_modelo','bonus','bonus_utilizado','valor_bonus', 'trade', 'bonus_dpto', 'trade_mkt_dpto']]
bonus_view_df = bonus_view_df[bonus_view_df['bonus_utilizado'] == 'PENDENTE VERIFICACAO']
bonus_view_df
# Out:
#         idnfsexterno    data_final_venda competencia  \
# 62    A251301941V210 2025-12-23 12:11:39    Dezembro
# 120   A251299801V210 2025-12-19 14:39:00    Dezembro
# 126   A251301641V210 2025-12-23 08:11:08    Dezembro
# 179   A251301091V210 2025-12-22 11:45:51    Dezembro
# 219   A251301111V210 2025-12-22 13:01:53    Dezembro
# 279    A25527791V210 2025-12-23 09:09:58    Dezembro
# 294    A25527711V210 2025-12-22 15:32:45    Dezembro
# 337    A25264441V210 2025-12-19 17:28:59    Dezembro
# 394   A251300311V210 2025-12-19 16:51:07    Dezembro
# 407   A251299671V210 2025-12-19 13:07:01    Dezembro
# 438   A251300691V210 2025-12-22 08:25:43    Dezembro
# 543    A25264661V210 2025-12-22 09:02:20    Dezembro
# 625    A25421071V210 2025-12-22 18:46:52    Dezembro
# 677    A25638361V210 2025-12-22 17:43:44    Dezembro
# 693    A25638091V210 2025-12-22 09:14:39    Dezembro
# 707    A25420921V210 2025-12-19 12:01:55    Dezembro
# 722    A25420991V210 2025-12-22 13:51:05    Dezembro
# ...
