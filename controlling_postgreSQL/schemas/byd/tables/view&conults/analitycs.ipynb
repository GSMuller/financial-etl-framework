# %%
import pandas as pd

# %%
import sys
sys.path.append('../../../../')  # Adiciona o diretório raiz ao path para importar conn.py

# %%
from conn import get_connection
engine = get_connection()  # Cria engine de conexão usando conn.py

# %%
byd_view = pd.read_sql("SELECT * FROM byd.bonus_view ORDER BY dta_processamento DESC", engine)
byd_view
# Out:
# C:\Users\giovanni.5683\AppData\Local\Temp\ipykernel_2964\146457635.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   byd_view = pd.read_sql("SELECT * FROM byd.bonus_view ORDER BY dta_processamento DESC", engine)
#         idnfsexterno revenda empresa numero_nota_fiscal serie_nota_fiscal  \
# 0     A251290551V210       1      25              29055                 1
# 1      A25525811V210       5      25               2581                 1
# 2     A251290541V070       1      25              29054                 1
# 3      A25262101V210       2      25               6210                 1
# 4      A25262061V210       2      25               6206                 1
# ...              ...     ...     ...                ...               ...
# 4682   A25716291V210       7      25               1629                 1
# ...
