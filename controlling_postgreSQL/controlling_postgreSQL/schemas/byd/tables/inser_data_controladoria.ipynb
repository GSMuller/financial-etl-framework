# %%
import pandas as pd
import sys

# %%
sys.path.append(r'c:\\Users\\giovanni.5683\\GITHUB\\controlling_postgreSQL')
from conn import get_connection # type: ignore

conn = get_connection()
cursor = conn.cursor()

# %%
conn.rollback()

# Ler o CSV
df = pd.read_csv(r'c:\Users\giovanni.5683\GITHUB\controlling_postgreSQL\Datasets\dpto.csv')

# Function to convert Brazilian format to numeric
def convert_br_to_numeric(value):
    if isinstance(value, str):
        # Remove dots (thousand separator) and replace comma with dot (decimal separator)
        value = value.replace('.', '').replace(',', '.')
    try:
        return float(value)
    except:
        return None

# Convert numeric columns from Brazilian format
df['bonus_dpto'] = df['bonus_dpto'].apply(convert_br_to_numeric)
df['trade_mkt_dpto'] = df['trade_mkt_dpto'].apply(convert_br_to_numeric)
df['rebate_dpto'] = df['rebate_dpto'].apply(convert_br_to_numeric)
df['ipva_dpto'] = df['ipva_dpto'].apply(convert_br_to_numeric)

# Atualizar a tabela usando UPDATE com base no idnfsexterno
for index, row in df.iterrows():
    # Skip rows where all target columns are NaN
    if pd.isna(row['bonus_dpto']) and pd.isna(row['trade_mkt_dpto']) and pd.isna(row['rebate_dpto']) and pd.isna(row['ipva_dpto']):
        continue
    
    idnfsexterno = str(row['idnfsexterno']).strip()  # Remove espaços extras
    print(f"Atualizando idnfsexterno: {idnfsexterno}")  # Debug
    query = """
    UPDATE byd.controladoria 
    SET bonus_dpto = %s,
        trade_mkt_dpto = %s,
        rebate_dpto = %s,
        ipva_dpto = %s
    WHERE idnfsexterno = %s
    """
    cursor.execute(query, (
        row['bonus_dpto'], 
        row['trade_mkt_dpto'], 
        row['rebate_dpto'], 
        row['ipva_dpto'], 
        idnfsexterno
    ))
    print(f"Registros afetados nesta linha: {cursor.rowcount}")  # Debug

conn.commit()
print(f"{cursor.rowcount} registros atualizados com sucesso!")
# Out:
# Atualizando idnfsexterno: A25331121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414541V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25622391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25514421V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25738931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25514361V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334241V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582201V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251224481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251231051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251222971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228541V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25243471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25514961V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415611V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244291V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25739141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331851V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2581981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251231051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251222971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228541V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25243471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25514961V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415611V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244291V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25739141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331851V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2581981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251230501V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251235931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515841V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251229101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415841V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251222411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515721V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251230501V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251235931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515841V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251229101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415841V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251222411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251228511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515721V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251236731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333521V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25741641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251236001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251223931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251235061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245261V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516841V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25742281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25622801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251229151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246811V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415301V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624951V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251236731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333521V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25741641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251236001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251223931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251235061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245261V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25244551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516841V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25742281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25622801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251229151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246811V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415301V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624951V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251225891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251232641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2592621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332791V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251232051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251232321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251225891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251232641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2592621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332791V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251232051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251232321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251233971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333491V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251233971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333491V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247081V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251240651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239591V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25741761V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334291V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334861V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251217501V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25622941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251221741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251221751V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247081V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251234651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251240651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239591V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25741761V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334291V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25334861V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251237641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251217501V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25247121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25622941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251221741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251221751V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25246511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333571V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623691V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25514951V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227491V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226871V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25740191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25624681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25333571V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25245131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25415191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623691V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25332801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25515831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25514951V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227491V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25623051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251226871V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414821V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227901V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331721V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251225701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25251151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25628301V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251241031V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248531V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247751V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25743601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25743321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414821V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251227901V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25414891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25331721V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251225701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25251151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25628301V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251241031V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248531V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247751V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25743601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25743321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746871V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251243261V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250491V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747031V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2594291V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249431V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25744191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746871V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251239801V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251243261V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250491V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747031V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2593921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2594291V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249431V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25744191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417261V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251245541V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251240951V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251242711V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25251371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625791V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252671V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251188025515582VD
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247711V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251245441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249791V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417261V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251245541V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251240951V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251242711V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25251371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625791V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252671V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251188025515582VD
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247711V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25747341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251245441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249791V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336331V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249351V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337361V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517431V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416501V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336331V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249351V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337361V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25517431V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416501V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251301V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251242701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251241731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251242041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248351V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417331V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251247191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251251301V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25516651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251242701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251241731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251242041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248351V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417331V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2583111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251241481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25251101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25518001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25248971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25743551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252691V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25337191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2583111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251241481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25745141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25251101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25417021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25518001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25336511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25248971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25743551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251252691V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251244101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25248981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25744271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25626861V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25628191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251248901V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25625521V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25627771V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25250281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25746881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2582761V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251246761V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251250991V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251249281V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25416581V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25249051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25628201V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25335461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25248981V210
# Registros afetados nesta linha: 1
# ...
# Atualizando idnfsexterno: A25343831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25756941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260821V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260831V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25419731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260851V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260861V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585271V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260871V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260881V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260891V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343901V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260901V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25419751V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286421V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343921V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25260911V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286431V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343931V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25756961V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286451V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25756971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25756981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25419771V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25419781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343961V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286571V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635421V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286611V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757081V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343991V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25756971V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25756981V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286461V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635401V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25419771V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25419781V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343941V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635411V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286511V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286551V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585311V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343961V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585321V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286561V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286571V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286601V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635421V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286611V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286621V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286631V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757081V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286641V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25343991V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344001V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286651V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344011V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344031V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286671V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286691V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286711V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2597141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286721V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344081V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286661V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344021V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344031V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286671V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585341V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344041V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286681V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344051V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286691V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344061V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286701V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344071V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286711V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635441V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2597141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286721V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344081V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525241V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585351V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585361V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344201V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344241V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635491V210
# Registros afetados nesta linha: 1
# 1 registros atualizados com sucesso!
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286731V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25525241V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261091V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25757181V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585351V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344111V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25261101V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585361V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A251286741V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344121V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635471V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344131V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344141V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344151V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585371V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585381V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344161V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344171V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344191V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A2585391V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344201V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344211V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635481V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344221V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344231V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344241V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25344251V210
# Registros afetados nesta linha: 1
# Atualizando idnfsexterno: A25635491V210
# Registros afetados nesta linha: 1
# 1 registros atualizados com sucesso!

# %%
# Consultar todos os dados da tabela byd.controladoria e criar um DataFrame para visualização
import pandas as pd

query = "SELECT * FROM byd.controladoria"
df_controladoria = pd.read_sql(query, conn)
df_controladoria.head()
