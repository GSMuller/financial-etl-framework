# %%
import pandas as pd
import sys

# %%
sys.path.append(r'c:\\Users\\giovanni.5683\\GITHUB\\controlling_postgreSQL')
from conn import get_connection # type: ignore

conn = get_connection()
cursor = conn.cursor()

# %%
conn.rollback()

# Ler o CSV
df = pd.read_csv(r'c:\Users\giovanni.5683\GITHUB\controlling_postgreSQL\Datasets\dta_emplacamento.csv')

# Atualizar a tabela usando UPDATE com base no idfsexterno
for index, row in df.iterrows():
    query = """
    UPDATE byd.db_vendas_byd 
    SET dta_emplacamento = %s 
    WHERE idnfsexterno = %s
    """
    cursor.execute(query, (row['dta_emplacamento'], row['idnfsexterno']))

conn.commit()
print(f"{cursor.rowcount} registros atualizados com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[6], line 13
#       7 for index, row in df.iterrows():
#       8     query = """
#       9     UPDATE byd.db_vendas_byd
#      10     SET dta_emplacamento = %s
#      11     WHERE idfsexterno = %s
#      12     """
# ---> 13     cursor.execute(query, (row['dta_emplacamento'], row['idnfsexterno']))
#      15 conn.commit()
#      16 print(f"{cursor.rowcount} registros atualizados com sucesso!")
#
# UndefinedColumn: column "idfsexterno" does not exist
# LINE 4:     WHERE idfsexterno = 'A251138871V210'
#                   ^
# HINT:  Perhaps you meant to reference the column "db_vendas_byd.idnfsexterno".
